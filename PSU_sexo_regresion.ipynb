# %%
#https://towardsdatascience.com/a-beginners-guide-to-linear-regression-in-python-with-scikit-learn-83a8f7ae2b4f 
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn import metrics
# %matplotlib inline

dataset = pd.read_excel('psusexo.xls')
dataset.shape
# Out:
# (26, 6)

# %%
dataset.describe()
# Out:
#          ID Sexo          Ano  Cantidad_alumnos  Promedio_lenguaje  \
# count  26.000000    26.000000         26.000000          26.000000
# mean    1.500000  2010.000000     208534.038462         501.114160
# std     0.509902     3.815757      48543.467313           2.543187
# min     1.000000  2004.000000      72493.000000         496.859904
# 25%     1.000000  2007.000000     191675.250000         499.373928
# 50%     1.500000  2010.000000     222892.000000         501.117745
# 75%     2.000000  2013.000000     239415.250000         503.101734
# max     2.000000  2016.000000     260393.000000         505.447532
#
#        Promedio_matematica
# count            26.000000
# mean            501.563849
# std              15.174235
# min             483.670178
# 25%             486.674031
# 50%             501.302861
# 75%             517.078577
# max             518.211153

# %%
dataset.columns
# Out:
# Index(['ID Sexo', 'Sexo', 'Ano', 'Cantidad_alumnos', 'Promedio_lenguaje',
#        'Promedio_matematica'],
#       dtype='object')

# %%
dataset.plot(x='Cantidad_alumnos', y='Promedio_lenguaje', style='o')  
plt.title('Cantidad_alumnos vs Promedio_lenguaje')  
plt.xlabel('Cantidad_alumnos')  
plt.ylabel('Promedio_lenguaje')  
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(dataset['Cantidad_alumnos'])

# %%
X = dataset['Cantidad_alumnos'].values.reshape(-1,1)
y = dataset['Promedio_lenguaje'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regressor = LinearRegression()  #definir el algoritmo
regressor.fit(X_train, y_train) # fit se usa para entrenar el modelo
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regressor.intercept_) # Para recuperar la intersección (b)
print(regressor.coef_) # Para recuperar la pendiente (a)
# Out:
# [501.54674577]
# [[-1.77611396e-06]]

# %%
y_pred = regressor.predict(X_test)

# %%
df = pd.DataFrame({'Actual': y_test.flatten(), 'Predictivo': y_pred.flatten()})
df
# Out:
#        Actual  Predictivo
# 0  499.674227  501.225999
# 1  501.901251  501.135710
# 2  503.446306  501.268887
# 3  505.147659  501.201997
# 4  496.859904  501.103186
# 5  498.384630  501.095552

# %%
df1 = df.head(25)
df1.plot(kind='bar',figsize=(16,10))
plt.grid(which='major', linestyle='-', linewidth='0.5', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.show()

# %%
import numpy as np
from sklearn import datasets, linear_model
import matplotlib.pyplot as plt  
boston = datasets.load_boston #datos de la librería de Scikit Learn
print(boston)
# Out:
# <function load_boston at 0x0000020727C579D8>

# %%
x = dataset.Cantidad_alumnos

# %%
from sklearn import linear_model

reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
#LinearRegression()
reg.coef_
# Out:
# array([0.5, 0.5])

# %%
>>> from sklearn import linear_model
>>> reg = linear_model.Ridge(alpha=.5)
>>> reg.fit([[0, 0], [0, 0], [1, 1]], [0, .1, 1])
#Ridge(alpha=0.5)
>>> reg.coef_
#array([0.34545455, 0.34545455])
>>> reg.intercept_
#0.13636...
# Out:
# 0.1363636363636364

# %%
import pandas as pd 
import numpy as np

from sklearn import datasets, linear_model
from sklearn.metrics import r2_score

regr=linear_model.LinearRegression()

psu = pd.read_excel('psu2016.xls') 
df=pd.DataFrame(psu)

x=df['ID_Tipo'] # se guarda en x la columna tipo 
y=df['ID _Institution']
X=x[:,np.newaxis] # no entiendo mucho esta columna 
print(X)
print(regr.fit(X,y)) # fit entrena el modelo 
print(regr.coef_) #conocer la pendiente
m=regr.coef_[0]
b=regr.intercept_

print('y={0}*x+{1}'.format(m,b))
# Out:
# [[1]
#  [1]
#  [1]
#  ...
#  [4]
#  [4]
#  [4]]
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# [1307.95140823]
# y=1307.9514082262456*x+-692.9756884472986

# %%
print(__doc__)

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Use only one feature
diabetes_X = diabetes_X[:, np.newaxis, 2]

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = regr.predict(diabetes_X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f'
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(diabetes_y_test, diabetes_y_pred))

# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Automatically created module for IPython interactive environment
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

reg = linear_model.LinearRegression()
reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])

LinearRegression()
reg.coef_
array([0.5, 0.5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-819d4a5feb61> in <module>
#       5 reg.fit([[0, 0], [1, 1], [2, 2]], [0, 1, 2])
#       6
# ----> 7 LinearRegression()
#       8 reg.coef_
#       9 array([0.5, 0.5])
#
# NameError: name 'LinearRegression' is not defined
